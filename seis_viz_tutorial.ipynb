# %% [markdown]
# # Seismic Visualization Tutorial
#
# Interactive visualization of a 3D seismic volume with horizon overlay, using the [Volve dataset](https://data.equinor.com/dataset/Volve) from Equinor.
#
# This notebook demonstrates:
# - Loading 3D SEG-Y data with [segyio](https://github.com/equinor/segyio)
# - Mapping a horizon surface onto the seismic grid
# - Interactive inline browsing with [ipywidgets](https://ipywidgets.readthedocs.io/en/stable/)
# - Exporting animations as GIF/MP4

# %%
from seis_viz import (
    load_seismic_cube,
    load_horizon,
    map_horizon_to_grid,
    get_corner_points,
    plot_map_and_section,
    create_animation,
)

# %% [markdown]
# ## Load seismic data and horizon

# %%
cube = load_seismic_cube("data/volve10r12-full-twt-sub3d.sgy")
hrz = load_horizon("data/hor_twt_hugin_fm_top.dat")
hrz_mapped = map_horizon_to_grid(cube, hrz)
corners = get_corner_points(cube)

print(f"Seismic cube: {dict(cube.dims)}")
print(f"Inlines: {int(cube.iline.min())} - {int(cube.iline.max())}")
print(f"Crosslines: {int(cube.xline.min())} - {int(cube.xline.max())}")
print(f"TWT: {float(cube.twt.min())} - {float(cube.twt.max())} ms")

# %% [markdown]
# ## Interactive viewer
#
# Use the slider to browse through inline sections. The left panel shows the map view with the current inline position; the right panel shows the seismic amplitude section with the Top Hugin horizon overlaid.

# %%
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import interactive

def viewer(inline_val):
    plot_map_and_section(cube, hrz_mapped, corners, inline_val)
    plt.show()

interactive_plot = interactive(
    viewer,
    inline_val=widgets.IntSlider(
        min=int(cube.iline.min()),
        max=int(cube.iline.max()),
        value=10120,
        description="Inline",
    ),
)
interactive_plot.children[-1].layout.height = "600px"
interactive_plot

# %% [markdown]
# ## Export animation
#
# Generate a GIF and MP4 sweeping through all inlines.

# %%
create_animation(cube, hrz_mapped, corners, "volve10r12-full-twt-sub3d", fps=10, fmt="gif")
create_animation(cube, hrz_mapped, corners, "volve10r12-full-twt-sub3d", fps=10, fmt="mp4")

# %% [markdown]
# ## References
#
# - [segyio](https://github.com/equinor/segyio) — fast SEG-Y reading
# - [ipywidgets](https://ipywidgets.readthedocs.io/en/stable/) — interactive Jupyter widgets
# - [Volve dataset](https://data.equinor.com/dataset/Volve) — open seismic data from Equinor ([license](https://datavillagesa.blob.core.windows.net/disclaimers/HRS%20and%20Terms%20and%20conditions%20for%20license%20to%20data%20-%20Volve.pdf))
#
# ## Acknowledgements
#
# The author thanks Equinor AS, the former Volve license partners ExxonMobil Exploration and Production Norway AS and Bayerngas (now Spirit Energy) for permission to use the Volve dataset.
